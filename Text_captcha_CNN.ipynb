# %%
#! pip install tqdm
# !  pip install keras

# %%
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import string

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import pad_sequences
from keras.utils.np_utils import to_categorical
from keras.models import load_model

import sklearn
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from tensorflow.python.client import device_lib

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

device_lib.list_local_devices()
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # Initialization

# %%
char_list = string.ascii_letters+string.digits
characters = set(char for char in char_list)
characters = sorted(list(characters))
img_height = 50
img_width = 200
vocab_len = len(characters)
# Map text to numeric labels 
char_to_num = {char:idx for idx, char in enumerate(characters)}

# Map numeric labels to text
num_to_char = {val:key for key, val in char_to_num.items()}

# %% [markdown]
# # Processing raw data

# %%
def raw_data_process(path):
    path = Path(path)
    images = sorted(list(map(str, list(path.glob("*.png")))))
    #split labels
    labels = [img.split(os.path.sep)[-1].split(".png")[0] for img in images]

    max_length = max([len(label) for label in labels])
    for i, label in enumerate(labels):
        if len(label) > 5:
            print(f"{i} {label}")
            print(images[i])

    print("Number of images found: ", len(images))
    print("Number of labels found: ", len(labels))
    print("Maximum label length: ",max_length)
    return images, labels, max_length

# %% [markdown]
# # Text Captcha preprocessing and normalization

# %% [markdown]
# Dictionary for mapping text character and numerical label

# %%
# Map text to numeric labels 
char_to_num = {char:idx for idx, char in enumerate(characters)}

# Map numeric labels to text
num_to_char = {val:key for key, val in char_to_num.items()}

# %% [markdown]
# Standardize and normalize image and input data for model

# %%
def images_process(images, labels,img_height, img_width):
    #input images path file and corresponding label
    #return matrix of grayscale img and encoded numerical labels


    def is_valid_captcha(captcha):
        for ch in captcha:
            if not ch in characters:
                return False
        return True
        
    #encode text label to list of number
    def encode_to_label(label):
        label = list(map(lambda x:char_to_num[x], label))
        return label

    def read_image(path, resize = True):

        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        if resize:
            img = cv2.resize(img, (img_width,img_height)) #standardize image

        img = (img/255).astype(np.float32) 
        img = img.T #transpose image, timestep will fit to the width of image
        return img
        
    def prep_data(images, labels):
        X = [read_image(img) for img in images] #pre-processing image
        y = [encode_to_label(label) for label in labels] #encode text label to numerical
        y = np.array(y)
        X = np.array(X)

        return X,y

    img, labels = prep_data(images,labels)
    return img, labels

# %%
data_dir = "samples" #replace by path to dataset
images, labels, max_length = raw_data_process(data_dir) #get raw data

X, y = images_process(images, labels,img_height,img_width)
# print(X[:10])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1, shuffle = True)
y_train = pad_sequences(y_train, maxlen=max_length, padding='post', value = len(characters))
y_test = pad_sequences(y_test, maxlen=max_length, padding='post', value = len(characters))
print(X_train.shape)

print(y_train.shape)
# Out:
# Number of images found:  1040
# Number of labels found:  1040
# Maximum label length:  5
# (832, 200, 50)
# (832, 5)

# %% [markdown]
# # Visualization

# %%
fig=plt.figure(figsize=(20, 10))
fig.add_subplot(2, 4, 1)
plt.imshow(X_train[0], cmap='gray')
#plt.imshow(X_train[0].transpose((1,0,2)), cmap='gray')
plt.title('Image from X_train with label '+ str(y_train[0]))
plt.axis('off')
fig.add_subplot(2, 4, 2)
plt.imshow(X_train[len(X_train)-1], cmap='gray')
#plt.imshow(X_train[935].transpose((1,0,2)), cmap='gray')
plt.title('Image from X_train with label '+ str(y_train[len(X_train)-1]))
plt.axis('off')
fig.add_subplot(2, 4, 3)
plt.imshow(X_test[0], cmap='gray')
#plt.imshow(X_test[0].transpose((1,0,2)), cmap='gray')
plt.title('Image from X_test with label '+ str(y_test[0]))
plt.axis('off')
fig.add_subplot(2, 4, 4)
plt.imshow(X_test[len(X_test)-1], cmap='gray')
#plt.imshow(X_test[103].transpose((1,0,2)), cmap='gray')
plt.title('Image from X_test with label '+ str(len(X_test)-1))
plt.axis('off')
# Out:
# (-0.5, 49.5, 199.5, -0.5)

# %% [markdown]
# # Create dataset

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, 
                data,
                labels,
                char_map,
                batch_size = 64,
                img_width = 200,
                img_height = 50,
                downsample_factor = 4,
                max_length = 5,
                shuffle = True):
        self.data = data
        self.labels = labels
        self.char_map = char_map
        self.batch_size = batch_size
        self.img_width = img_width
        self.img_height = img_height
        self.downsample_factor = downsample_factor
        self.max_length = max_length
        self.shuffle = shuffle
        self.indices = np.arange(len(data))    
        self.on_epoch_end()
    def __len__(self):
        return int(np.floor(len(self.data)/self.batch_size))

    def __getitem__(self,index):
        'Generate one batch of data'
        # Generate indexes of the batch
        batch_index = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_image = np.ones((self.batch_size, self.img_width, self.image_height, 1), dtype = np.float32)
        batch_labels = np.ones((self.batch_size, self.max_length), dtype=np.float32)
        input_length = np.ones((self.batch_size, 1), dtype = np.int64)

# %% [markdown]
# # CNN model

# %%
downsample_factor = 8 #pool size =2 with 4 pooling layers
def build_cnn_model():
    input_img = layers.Input(shape=(img_width, img_height, 1), name ="input_data", dtype = "float32")
    labels = layers.Input(name = "input_label", shape = (max_length,), dtype="float32")

    #Conv Layers
    conv_1 = layers.Conv2D(32, (3,3), 
                            activation= "relu", 
                            kernel_initializer="he_normal", 
                            padding = "same", 
                            name = "Conv1")(input_img)
    pool_1 = layers.MaxPooling2D((2,2), name = "pool1")(conv_1)

    conv_2 = layers.Conv2D(64, (3,3), activation= "relu", kernel_initializer="he_normal", padding = "same", name = "Conv2")(pool_1)
    pool_2 = layers.MaxPooling2D((2,2), name = "pool2")(conv_2)

    conv_3 = layers.Conv2D(120, (3,3), activation= "relu", kernel_initializer="he_normal", padding = "same", name = "Conv3")(pool_2)
    conv_3 = layers.Dropout(0.2)(conv_3) #drop connection with ratio 0.2 to avoid overfitting
    pool_3 = layers.MaxPooling2D((2,2), name = "pool3")(conv_3)

    # conv_4 = layers.Conv2D(256, (3,3), activation= "relu", kernel_initializer="he_normal", padding = "same", name = "Conv4")(pool_3)
    # batch_norm_4 = layers.BatchNormalization()(conv_4)
    # pool_4 = layers.MaxPooling2D((2,2), name = "pool4")(batch_norm_4)

    # Reshape layer for RNN input
    new_shape = ((img_width //downsample_factor),(img_height // downsample_factor)*120)
    reshape = layers.Reshape(target_shape=(max_length,new_shape[1]*new_shape[0]//max_length), name = "reshape")(pool_3)
    dense_1 = layers.Dense(256, activation= "relu", name = "dense_1") (reshape) #FC layer
    dense_1 = layers.Dropout(0.2)(dense_1)
    dense_2 = layers.Dense(128, activation= "relu", name = "dense_2") (dense_1) #FC layer

    # conv_encoder = layers.Dropout(0.2)(conv_encoder) #drop connection with ratio 0.2 to avoid overfitting

    #Single CNN model 
    output = layers.Dense(vocab_len, activation= "softmax", name ="CNN_output")(dense_2)
    cnn_model = keras.models.Model(inputs = input_img, outputs = output, name = "CNN_model")
    cnn_model.compile(optimizer = keras.optimizers.Adam(), loss="sparse_categorical_crossentropy", metrics = "accuracy")
    return cnn_model
cnn_model = build_cnn_model()
cnn_model.summary()

# %%
# Out:
# Model: "CNN_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_data (InputLayer)     [(None, 200, 50, 1)]      0
#
#  Conv1 (Conv2D)              (None, 200, 50, 32)       320
#
#  pool1 (MaxPooling2D)        (None, 100, 25, 32)       0
#
#  Conv2 (Conv2D)              (None, 100, 25, 64)       18496
#
#  pool2 (MaxPooling2D)        (None, 50, 12, 64)        0
#
#  Conv3 (Conv2D)              (None, 50, 12, 120)       69240
#
#  dropout (Dropout)           (None, 50, 12, 120)       0
#
#  pool3 (MaxPooling2D)        (None, 25, 6, 120)        0
#
#  reshape (Reshape)           (None, 5, 3600)           0
#
#  dense_1 (Dense)             (None, 5, 256)            921856
#
#  dropout_1 (Dropout)         (None, 5, 256)            0
#
#  dense_2 (Dense)             (None, 5, 128)            32896
#
#  CNN_output (Dense)          (None, 5, 62)             7998
#
# =================================================================
# Total params: 1,050,806
# Trainable params: 1,050,806
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True)

# print (y_train[:3])

# history = cnn_model.fit(x = X_train, y = y_train, validation_data=(X_test, y_test), epochs=60, batch_size = 32, callbacks = [early_stopping])

# %% [markdown]
# # CRNN model with CTC loss layer

# %%
#Customize CTC layer for output
class CTCLayer(layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        return loss

# %%
downsample_factor = 8 #pool size =2 with 3 pooling layers
def build_model():
    input_img = layers.Input(shape=(img_width,img_height, 1), name ="input_data", dtype = "float32")
    labels = layers.Input(name = "input_label", shape = max_length, dtype="float32")

    #Conv Layers
    conv_1 = layers.Conv2D(32, (3,3), 
                            activation= "relu", 
                            kernel_initializer="he_normal", 
                            padding = "same", 
                            name = "Conv1")(input_img)
    pool_1 = layers.MaxPooling2D((2,2), name = "pool1")(conv_1)

    conv_2 = layers.Conv2D(64, (3,3), activation= "relu", kernel_initializer="he_normal", padding = "same", name = "Conv2")(pool_1)
    pool_2 = layers.MaxPooling2D((2,2), name = "pool2")(conv_2)

    conv_3 = layers.Conv2D(128, (3,3), activation= "relu", kernel_initializer="he_normal", padding = "same", name = "Conv3")(pool_2)
    conv_3 = layers.Dropout(0.2)(conv_3) #drop connection with ratio 0.2 to avoid overfitting
    pool_3 = layers.MaxPooling2D((2,2), name = "pool3")(conv_3)

    # 3 maxpooling layers with stride = 2
    # Which leads to 8x smaller downsampled feature maps
    # Flatten the last conv_3 layer with 128 filters in to a feature vector and go through a Fully-Connected NN 
    # to summarize the learning features and being used as input for classification stage (RNN)
    new_shape = ((img_width //downsample_factor),(img_height // downsample_factor)*128)
    reshape = layers.Reshape(target_shape=new_shape, name = "reshape")(pool_3)
    #Fully-connected network
    dense_1 = layers.Dense(128, activation= "relu", name = "dense_1") (reshape) #FC layer
    dense_2 = layers.Dense(64, activation= "relu", name = "dense_2") (dense_1) #FC layer
    dense_2 = layers.Dropout(0.2)(dense_2)
    conv_encoder = layers.Dense(64, activation= "relu", name = "cnn_encoder") (dense_2) #FC layer
    conv_encoder = layers.Dropout(0.2)(conv_encoder) #drop connection with ratio 0.2 to avoid overfitting

    #RNNs
    lstm_1 = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.02))(conv_encoder)
    lstm_2 = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.2))(lstm_1)
    #transcipt layer
    prediction = layers.Dense(vocab_len + 1, activation="softmax", name = "pred")(lstm_2)
    # Add CTC layer for calculating CTC loss at each step
    output = CTCLayer(name="ctc_loss")(labels, prediction)

    # Define the model
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="ocr_model_v1")
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(optimizer=opt)
    return model
print(X_train.shape)
print(y_train.shape)

model = build_model()
print(model.input)
model.summary()
# Out:
# (832, 200, 50)
# (832, 5)
# [<KerasTensor: shape=(None, 200, 50, 1) dtype=float32 (created by layer 'input_data')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'input_label')>]
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_data (InputLayer)        [(None, 200, 50, 1)  0           []
#                                 ]
#
#  Conv1 (Conv2D)                 (None, 200, 50, 32)  320         ['input_data[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 100, 25, 32)  0           ['Conv1[0][0]']
#
#  Conv2 (Conv2D)                 (None, 100, 25, 64)  18496       ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)           (None, 50, 12, 64)   0           ['Conv2[0][0]']
#
#  Conv3 (Conv2D)                 (None, 50, 12, 128)  73856       ['pool2[0][0]']
#
#  dropout_2 (Dropout)            (None, 50, 12, 128)  0           ['Conv3[0][0]']
#
#  pool3 (MaxPooling2D)           (None, 25, 6, 128)   0           ['dropout_2[0][0]']
#
#  reshape (Reshape)              (None, 25, 768)      0           ['pool3[0][0]']
#
#  dense_1 (Dense)                (None, 25, 128)      98432       ['reshape[0][0]']
#
#  dense_2 (Dense)                (None, 25, 64)       8256        ['dense_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 25, 64)       0           ['dense_2[0][0]']
#
#  cnn_encoder (Dense)            (None, 25, 64)       4160        ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 25, 64)       0           ['cnn_encoder[0][0]']
#
#  bidirectional (Bidirectional)  (None, 25, 256)      197632      ['dropout_4[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 25, 128)     164352      ['bidirectional[0][0]']
#  )
#
#  input_label (InputLayer)       [(None, 5)]          0           []
#
#  pred (Dense)                   (None, 25, 63)       8127        ['bidirectional_1[0][0]']
#
#  ctc_loss (CTCLayer)            (None, 1)            0           ['input_label[0][0]',
#                                                                   'pred[0][0]']
#
# ==================================================================================================
# Total params: 573,631
# Trainable params: 573,631
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)
# print ([X_train, y_train])
# Train the model
train = [X_train, y_train]


val = [X_test, y_test]
history = model.fit( train, y = np.zeros(len(y_train)), validation_data=([X_test, y_test],np.zeros(len(y_test))), epochs=150, callbacks=[early_stopping])
# history = model.fit( train, validation_data=[X_test, y_test], epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/150
# 26/26 [==============================] - 6s 246ms/step - loss: 0.7889 - val_loss: 0.4053
# Epoch 2/150
# 26/26 [==============================] - 6s 241ms/step - loss: 0.6196 - val_loss: 0.2978
# Epoch 3/150
# 26/26 [==============================] - 6s 238ms/step - loss: 0.5059 - val_loss: 0.2440
# Epoch 4/150
# 26/26 [==============================] - 6s 234ms/step - loss: 0.3895 - val_loss: 0.1939
# Epoch 5/150
# 26/26 [==============================] - 6s 230ms/step - loss: 0.3477 - val_loss: 0.1534
# Epoch 6/150
# 26/26 [==============================] - 6s 227ms/step - loss: 0.3100 - val_loss: 0.1464
# Epoch 7/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.3046 - val_loss: 0.1429
# Epoch 8/150
# 26/26 [==============================] - 6s 227ms/step - loss: 0.3094 - val_loss: 0.1285
# Epoch 9/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.2250 - val_loss: 0.1007
# Epoch 10/150
# 26/26 [==============================] - 6s 229ms/step - loss: 0.1902 - val_loss: 0.0992
# Epoch 11/150
# 26/26 [==============================] - 6s 231ms/step - loss: 0.1846 - val_loss: 0.0804
# Epoch 12/150
# 26/26 [==============================] - 6s 227ms/step - loss: 0.1637 - val_loss: 0.0763
# Epoch 13/150
# 26/26 [==============================] - 6s 229ms/step - loss: 0.1691 - val_loss: 0.0907
# Epoch 14/150
# 26/26 [==============================] - 6s 227ms/step - loss: 0.2075 - val_loss: 0.0740
# Epoch 15/150
# 26/26 [==============================] - 6s 229ms/step - loss: 0.1865 - val_loss: 0.0639
# Epoch 16/150
# 26/26 [==============================] - 6s 231ms/step - loss: 0.1530 - val_loss: 0.0526
# Epoch 17/150
# 26/26 [==============================] - 6s 233ms/step - loss: 0.1216 - val_loss: 0.0478
# Epoch 18/150
# 26/26 [==============================] - 6s 230ms/step - loss: 0.1118 - val_loss: 0.0545
# Epoch 19/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0993 - val_loss: 0.0447
# Epoch 20/150
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0924 - val_loss: 0.0418
# Epoch 21/150
# 26/26 [==============================] - 6s 234ms/step - loss: 0.1346 - val_loss: 0.0789
# Epoch 22/150
# 26/26 [==============================] - 6s 232ms/step - loss: 0.1586 - val_loss: 0.0598
# Epoch 23/150
# 26/26 [==============================] - 6s 230ms/step - loss: 0.1169 - val_loss: 0.0636
# Epoch 24/150
# 26/26 [==============================] - 6s 230ms/step - loss: 0.1118 - val_loss: 0.0401
# Epoch 25/150
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0951 - val_loss: 0.0324
# Epoch 26/150
# 26/26 [==============================] - 7s 250ms/step - loss: 0.0830 - val_loss: 0.0383
# Epoch 27/150
# 26/26 [==============================] - 7s 255ms/step - loss: 0.1015 - val_loss: 0.0437
# Epoch 28/150
# 26/26 [==============================] - 7s 267ms/step - loss: 0.0782 - val_loss: 0.0261
# Epoch 29/150
# 26/26 [==============================] - 7s 290ms/step - loss: 0.0799 - val_loss: 0.0248
# Epoch 30/150
# 26/26 [==============================] - 6s 242ms/step - loss: 0.0850 - val_loss: 0.0244
# Epoch 31/150
# 26/26 [==============================] - 6s 236ms/step - loss: 0.0712 - val_loss: 0.0210
# Epoch 32/150
# 26/26 [==============================] - 6s 226ms/step - loss: 0.0688 - val_loss: 0.0249
# Epoch 33/150
# 26/26 [==============================] - 6s 232ms/step - loss: 0.0548 - val_loss: 0.0259
# Epoch 34/150
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0772 - val_loss: 0.0221
# Epoch 35/150
# 26/26 [==============================] - 6s 245ms/step - loss: 0.0698 - val_loss: 0.0293
# Epoch 36/150
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0643 - val_loss: 0.0188
# Epoch 37/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0369 - val_loss: 0.0189
# Epoch 38/150
# 26/26 [==============================] - 6s 245ms/step - loss: 0.0349 - val_loss: 0.0162
# Epoch 39/150
# 26/26 [==============================] - 7s 272ms/step - loss: 0.0498 - val_loss: 0.0170
# Epoch 40/150
# 26/26 [==============================] - 7s 256ms/step - loss: 0.0417 - val_loss: 0.0196
# Epoch 41/150
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0466 - val_loss: 0.0235
# Epoch 42/150
# 26/26 [==============================] - 6s 245ms/step - loss: 0.0436 - val_loss: 0.0157
# Epoch 43/150
# 26/26 [==============================] - 6s 232ms/step - loss: 0.0511 - val_loss: 0.0164
# Epoch 44/150
# 26/26 [==============================] - 8s 297ms/step - loss: 0.0465 - val_loss: 0.0173
# Epoch 45/150
# 26/26 [==============================] - 6s 247ms/step - loss: 0.0303 - val_loss: 0.0167
# Epoch 46/150
# 26/26 [==============================] - 7s 266ms/step - loss: 0.0433 - val_loss: 0.0357
# Epoch 47/150
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0515 - val_loss: 0.0263
# Epoch 48/150
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0415 - val_loss: 0.0339
# Epoch 49/150
# 26/26 [==============================] - 7s 255ms/step - loss: 0.0385 - val_loss: 0.0144
# Epoch 50/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0434 - val_loss: 0.0297
# Epoch 51/150
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0364 - val_loss: 0.0175
# Epoch 52/150
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0330 - val_loss: 0.0145
# Epoch 53/150
# 26/26 [==============================] - 6s 238ms/step - loss: 0.0421 - val_loss: 0.0274
# Epoch 54/150
# 26/26 [==============================] - 6s 231ms/step - loss: 0.0369 - val_loss: 0.0133
# Epoch 55/150
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0386 - val_loss: 0.0285
# Epoch 56/150
# 26/26 [==============================] - 6s 224ms/step - loss: 0.0529 - val_loss: 0.0342
# Epoch 57/150
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0752 - val_loss: 0.0173
# Epoch 58/150
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0748 - val_loss: 0.0339
# Epoch 59/150
# 26/26 [==============================] - 6s 233ms/step - loss: 0.0873 - val_loss: 0.0131
# Epoch 60/150
# 26/26 [==============================] - 6s 235ms/step - loss: 0.0403 - val_loss: 0.0310
# Epoch 61/150
# 26/26 [==============================] - 7s 252ms/step - loss: 0.0434 - val_loss: 0.0417
# Epoch 62/150
# 26/26 [==============================] - 6s 237ms/step - loss: 0.0381 - val_loss: 0.0210
# Epoch 63/150
# 26/26 [==============================] - 6s 243ms/step - loss: 0.0528 - val_loss: 0.0208
# Epoch 64/150
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0571 - val_loss: 0.0186
# Epoch 65/150
# 26/26 [==============================] - 8s 300ms/step - loss: 0.0316 - val_loss: 0.0149
# Epoch 66/150
# 26/26 [==============================] - 7s 251ms/step - loss: 0.0632 - val_loss: 0.0191
# Epoch 67/150
# 26/26 [==============================] - 7s 252ms/step - loss: 0.0445 - val_loss: 0.0269
# Epoch 68/150
# 26/26 [==============================] - 6s 243ms/step - loss: 0.0235 - val_loss: 0.0137
# Epoch 69/150
# 26/26 [==============================] - 7s 256ms/step - loss: 0.0276 - val_loss: 0.0196
# Epoch 70/150
# 26/26 [==============================] - 7s 274ms/step - loss: 0.0674 - val_loss: 0.0112
# Epoch 71/150
# 26/26 [==============================] - 7s 268ms/step - loss: 0.0489 - val_loss: 0.0219
# Epoch 72/150
# 26/26 [==============================] - 7s 259ms/step - loss: 0.0589 - val_loss: 0.0368
# Epoch 73/150
# 12/26 [============>.................] - ETA: 3s - loss: 0.0576

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('CTC loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %%
model.save('./MyModel_tf',save_format='tf')


# loading the saved model
# loaded_model = tf.keras.models.load_model('./MyModel_tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla, lstm_cell_1_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./MyModel_tf/assets
# INFO:tensorflow:Assets written to: ./MyModel_tf/assets

# %%
prediction_model = keras.models.Model(
    model.get_layer(name="input_data").input, model.get_layer(name="pred").output
)
prediction_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_data (InputLayer)     [(None, 200, 50, 1)]      0
#
#  Conv1 (Conv2D)              (None, 200, 50, 32)       320
#
#  pool1 (MaxPooling2D)        (None, 100, 25, 32)       0
#
#  Conv2 (Conv2D)              (None, 100, 25, 64)       18496
#
#  pool2 (MaxPooling2D)        (None, 50, 12, 64)        0
#
#  Conv3 (Conv2D)              (None, 50, 12, 128)       73856
#
#  dropout_2 (Dropout)         (None, 50, 12, 128)       0
#
#  pool3 (MaxPooling2D)        (None, 25, 6, 128)        0
#
#  reshape (Reshape)           (None, 25, 768)           0
#
#  dense_1 (Dense)             (None, 25, 128)           98432
#
#  dense_2 (Dense)             (None, 25, 64)            8256
#
#  dropout_3 (Dropout)         (None, 25, 64)            0
#
#  cnn_encoder (Dense)         (None, 25, 64)            4160
#
#  dropout_4 (Dropout)         (None, 25, 64)            0
#
#  bidirectional (Bidirectiona  (None, 25, 256)          197632
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 25, 128)          164352
#  nal)
#
#  pred (Dense)                (None, 25, 63)            8127
#
# =================================================================
# Total params: 573,631
# Trainable params: 573,631
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = prediction_model.predict(X_test) # y_pred shape = (104,50,20)

def decode_to_text(output):
    text_label = ""
    for c in output:
        if c in num_to_char:
            text_label += num_to_char[c]

    return text_label
def decode_model_output(y_pred):
    result = keras.backend.ctc_decode(y_pred, 
                                        input_length=np.ones(y_pred.shape[0])*y_pred.shape[1],
                                        greedy=True)[0][0][:,:max_length] 
    labels = []
    for output in result.numpy():
        labels.append(decode_to_text(output))

    return labels

label_pred = decode_model_output(y_pred)
print(y_test[1])
for i in range(len(X_test)):
    image = X_test[i]
    label_truth = decode_to_text(y_test[i])
    print(f'Ground truth: {label_truth} \t Predicted: {label_pred[i]}')
# Out:
# 7/7 [==============================] - 3s 62ms/step
# [38 37  8 38 41]
# Ground truth: mb4en 	 Predicted: mb4en
# Ground truth: cb8cf 	 Predicted: cb8cf
# Ground truth: n336e 	 Predicted: n336e
# Ground truth: f5e5e 	 Predicted: f5e5e
# Ground truth: 3eny7 	 Predicted: 3eny7
# Ground truth: xdcn4 	 Predicted: xdcn4
# Ground truth: 5npdn 	 Predicted: 5npdn
# Ground truth: bgem5 	 Predicted: bgem5
# Ground truth: gxx2p 	 Predicted: gxx2p
# Ground truth: 5n245 	 Predicted: 5n245
# Ground truth: 8c23f 	 Predicted: 8c23f
# Ground truth: 8fexn 	 Predicted: 8fexn
# Ground truth: 3xcgg 	 Predicted: 3xcgg
# Ground truth: dyxnc 	 Predicted: dyxnc
# Ground truth: d75b5 	 Predicted: d75b5
# Ground truth: e6b7y 	 Predicted: e6b7y
# Ground truth: 74853 	 Predicted: 74853
# Ground truth: x5nyn 	 Predicted: x5nyn
# Ground truth: 6xen4 	 Predicted: 6xen4
# Ground truth: 32dnn 	 Predicted: 32dnn
# Ground truth: 2nf26 	 Predicted: 2nf26
# Ground truth: g7wxw 	 Predicted: g7wxw
# Ground truth: ncyx8 	 Predicted: ncyx8
# Ground truth: x7547 	 Predicted: x7547
# Ground truth: 3ebnn 	 Predicted: 3ebnn
# Ground truth: c6f8g 	 Predicted: c6f8g
# Ground truth: cfw6e 	 Predicted: cfw6e
# Ground truth: edwny 	 Predicted: edwny
# Ground truth: x4f7g 	 Predicted: x4f7g
# Ground truth: 57b27 	 Predicted: 57b27
# Ground truth: y33nm 	 Predicted: y33nm
# Ground truth: 2fxgd 	 Predicted: 2fxgd
# Ground truth: 2wc38 	 Predicted: 2wc38
# Ground truth: 556wd 	 Predicted: 556wd
# Ground truth: 36nx4 	 Predicted: 36nx4
# Ground truth: y48c3 	 Predicted: y48c3
# Ground truth: b6f2p 	 Predicted: b6f2p
# Ground truth: cwdnx 	 Predicted: cwdnx
# Ground truth: 244e2 	 Predicted: 244e2
# Ground truth: nc4yg 	 Predicted: nc4yg
# Ground truth: 3ye2e 	 Predicted: 3ye2e
# Ground truth: n7ff2 	 Predicted: n7ff2
# Ground truth: 428b6 	 Predicted: 428b6
# Ground truth: d7c5x 	 Predicted: d7c5x
# Ground truth: dw8d3 	 Predicted: dw8d3
# Ground truth: x3deb 	 Predicted: x3deb
# Ground truth: 88y52 	 Predicted: 88y52
# Ground truth: 8npe3 	 Predicted: 8npe3
# Ground truth: nbfx5 	 Predicted: nbfx5
# Ground truth: ffpxf 	 Predicted: ffpxf
# Ground truth: 3pe4g 	 Predicted: 3pe4g
# Ground truth: b5nmm 	 Predicted: b5nmm
# Ground truth: c4bgd 	 Predicted: c4bgd
# Ground truth: c5xne 	 Predicted: c5xne
# Ground truth: 6ng6n 	 Predicted: 6ng6n
# Ground truth: 5wddw 	 Predicted: 5wddw
# Ground truth: 7p852 	 Predicted: 7p852
# Ground truth: 4743p 	 Predicted: 4743p
# Ground truth: 43gey 	 Predicted: 43gey
# Ground truth: 5mcy7 	 Predicted: 5mcy7
# Ground truth: 7m8px 	 Predicted: 7m8px
# Ground truth: 46mbm 	 Predicted: 46mbm
# Ground truth: 6g45w 	 Predicted: 6g45w
# Ground truth: f75cx 	 Predicted: f75cx
# Ground truth: w2n7e 	 Predicted: w2n7e
# Ground truth: neecd 	 Predicted: neecd
# Ground truth: d2ycw 	 Predicted: d2ycw
# Ground truth: 2nbcx 	 Predicted: 2mbcx
# Ground truth: x37bf 	 Predicted: x37bf
# Ground truth: yf424 	 Predicted: yf424
# Ground truth: nwg2m 	 Predicted: nwg2m
# Ground truth: xdn65 	 Predicted: xdn65
# Ground truth: y7d75 	 Predicted: y7d75
# Ground truth: cen55 	 Predicted: cen55
# Ground truth: 4egem 	 Predicted: 4egem
# Ground truth: 6ng6w 	 Predicted: 6ng6w
# Ground truth: 3n3cf 	 Predicted: 3n3cf
# Ground truth: myf82 	 Predicted: myf82
# Ground truth: 7pn5g 	 Predicted: 7pn5g
# Ground truth: 6xpme 	 Predicted: 6xpme
# Ground truth: wdww8 	 Predicted: wdww8
# Ground truth: 5gcd3 	 Predicted: 5gcd3
# Ground truth: gpxng 	 Predicted: gpxng
# Ground truth: yx2d4 	 Predicted: yx2d4
# Ground truth: nnn5p 	 Predicted: nnn5p
# Ground truth: dbpcd 	 Predicted: dbpcd
# Ground truth: p8wwf 	 Predicted: p8wwf
# Ground truth: y32yy 	 Predicted: y32yy
# Ground truth: 6f857 	 Predicted: 6f857
# Ground truth: 268g2 	 Predicted: 268g2
# Ground truth: xe6eb 	 Predicted: xe6eb
# Ground truth: nfndw 	 Predicted: nfndw
# Ground truth: f8f8g 	 Predicted: f8f8g
# Ground truth: bnc5f 	 Predicted: bnc5f
# Ground truth: ncw4g 	 Predicted: ncw4g
# Ground truth: dd764 	 Predicted: dd764
# Ground truth: 37d52 	 Predicted: 37d52
# Ground truth: 8gecm 	 Predicted: 8gecm
# Ground truth: g55b4 	 Predicted: g55b4
# Ground truth: 4ycex 	 Predicted: 4ycex
# Ground truth: n5w5g 	 Predicted: n5w5g
# Ground truth: 6ecbn 	 Predicted: 6ecbn
# Ground truth: 67dey 	 Predicted: 67dey
# Ground truth: 5n732 	 Predicted: 5n732
# Ground truth: x5f54 	 Predicted: x5f54
# Ground truth: excmn 	 Predicted: excmn
# Ground truth: m5ym2 	 Predicted: m5ym2
# Ground truth: e7x45 	 Predicted: e7x45
# Ground truth: b84xc 	 Predicted: b84xc
# Ground truth: 4f8yp 	 Predicted: 4f8yp
# Ground truth: b4y5x 	 Predicted: b4y5x
# Ground truth: nnfx3 	 Predicted: nnfx3
# Ground truth: 3nw7w 	 Predicted: 3nw7w
# Ground truth: xymfn 	 Predicted: xymfn
# Ground truth: e46pd 	 Predicted: e46pd
# Ground truth: 8n56m 	 Predicted: 8n56m
# Ground truth: c8n8c 	 Predicted: c8n8c
# Ground truth: 5np4m 	 Predicted: 5np4m
# Ground truth: mwxwp 	 Predicted: mwxwp
# Ground truth: 5ep3n 	 Predicted: 5ep3n
# Ground truth: 8w754 	 Predicted: 8w754
# Ground truth: w7e6m 	 Predicted: w7e6m
# Ground truth: 6dd2y 	 Predicted: 6dd2y
# Ground truth: 5x7x5 	 Predicted: 5x7x5
# Ground truth: 5x5nx 	 Predicted: 5x5nx
# Ground truth: n464c 	 Predicted: n464c
# Ground truth: dw3nn 	 Predicted: dw3nn
# Ground truth: 36bc2 	 Predicted: 36bc2
# Ground truth: 25m6p 	 Predicted: 25m6p
# Ground truth: pn7pn 	 Predicted: pn7pn
# Ground truth: e84n2 	 Predicted: e84n2
# Ground truth: d3c8y 	 Predicted: d3c8y
# Ground truth: c43b4 	 Predicted: c43b4
# Ground truth: pnnwy 	 Predicted: pnnwy
# Ground truth: gwn53 	 Predicted: gwn53
# Ground truth: e2mg2 	 Predicted: e2mg2
# Ground truth: wc2bd 	 Predicted: wc2bd
# Ground truth: 62nb3 	 Predicted: 62nb3
# Ground truth: cfc2y 	 Predicted: cfc2y
# Ground truth: 8gmc4 	 Predicted: 8gmc4
# Ground truth: 6b4w6 	 Predicted: 6b4w6
# Ground truth: 23mdg 	 Predicted: 23mdg
# Ground truth: pwmbn 	 Predicted: pwmbn
# Ground truth: 6end3 	 Predicted: 6end3
# Ground truth: gc277 	 Predicted: gc277
# Ground truth: mmfm6 	 Predicted: mmfm6
# Ground truth: d378n 	 Predicted: d378n
# Ground truth: ccf2w 	 Predicted: ccf2w
# Ground truth: yeyn4 	 Predicted: yeyn4
# Ground truth: d3ycn 	 Predicted: d3ycn
# Ground truth: 53wb8 	 Predicted: 53wb8
# Ground truth: g2577 	 Predicted: g2577
# Ground truth: 2356g 	 Predicted: 2356g
# Ground truth: ng6yp 	 Predicted: ng6yp
# Ground truth: 3bnyf 	 Predicted: 3bnyf
# Ground truth: n2by7 	 Predicted: n2by7
# Ground truth: 4n3mn 	 Predicted: 4n3mn
# Ground truth: bxxfc 	 Predicted: bxxfc
# Ground truth: myc3c 	 Predicted: myc3c
# Ground truth: xnfx5 	 Predicted: xnfx5
# Ground truth: pf4nb 	 Predicted: pf4nb
# Ground truth: cwgyx 	 Predicted: cwgyx
# Ground truth: exycn 	 Predicted: exycn
# Ground truth: 3bx86 	 Predicted: 3bx86
# Ground truth: 44ype 	 Predicted: 44ype
# Ground truth: gnbn4 	 Predicted: gnbn4
# Ground truth: ncfgb 	 Predicted: ncfgb
# Ground truth: 43xfe 	 Predicted: 43xfe
# Ground truth: 243mm 	 Predicted: 243mm
# Ground truth: fp762 	 Predicted: fp762
# Ground truth: 5nggg 	 Predicted: 5nggg
# Ground truth: nxcmn 	 Predicted: nxcmn
# Ground truth: ewcf5 	 Predicted: ewcf5
# Ground truth: fcmem 	 Predicted: fcmem
# Ground truth: y53c2 	 Predicted: y53c2
# Ground truth: m22e3 	 Predicted: m22e3
# Ground truth: c482b 	 Predicted: c482b
# Ground truth: 24f6w 	 Predicted: 24f6w
# Ground truth: ny8np 	 Predicted: ny8np
# Ground truth: 34fxm 	 Predicted: 34fxm
# Ground truth: mfb3x 	 Predicted: mfb3x
# Ground truth: p2ym2 	 Predicted: p2ym2
# Ground truth: mfc35 	 Predicted: mfc35
# Ground truth: e8dxn 	 Predicted: e8dxn
# Ground truth: 3n2b4 	 Predicted: 3n2b4
# Ground truth: yw7ny 	 Predicted: yw7ny
# Ground truth: 56c34 	 Predicted: 56c34
# Ground truth: bw44w 	 Predicted: bw44w
# Ground truth: 488de 	 Predicted: 488de
# Ground truth: 76y6f 	 Predicted: 76y6f
# Ground truth: gfxcc 	 Predicted: gfxcc
# Ground truth: x277e 	 Predicted: x277e
# Ground truth: ddpyb 	 Predicted: ddpyb
# Ground truth: 8ypdn 	 Predicted: 8ypdn
# Ground truth: 87nym 	 Predicted: 87nym
# Ground truth: nxxf8 	 Predicted: nxxf8
# Ground truth: c3n8x 	 Predicted: c3n8x
# Ground truth: 7pcd7 	 Predicted: 7pcd7
# Ground truth: ycmcw 	 Predicted: ycmcw
# Ground truth: pdw38 	 Predicted: pdw38
# Ground truth: d7nn3 	 Predicted: d7nn3
# Ground truth: 3fbxd 	 Predicted: 3fbxd
# Ground truth: 5f3gf 	 Predicted: 5f3gf
# Ground truth: m74dm 	 Predicted: m74dm
# Ground truth: d22y5 	 Predicted: d22y5
# Ground truth: nmw46 	 Predicted: nmw46
# Ground truth: y2436 	 Predicted: y2436
# Ground truth: x76mn 	 Predicted: x76mn

# %%
model.save('partly_trained_2.h5')
